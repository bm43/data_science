# %%
import requests
import pandas as pd
import time
API_KEY='AIzaSyDwhgWOs0oJcINseK8F944oT0zH6v_V1LQ'
#channel_id='UCutUv2A6NxOyiF0Fk43TRbA'

# %%
q='spinners'
url = 'https://youtube.googleapis.com/youtube/v3/search?q='+q+\
'&type=video&order=relevance&part=id%2Csnippet&maxResults=50&key='+API_KEY+'&alt=json'
response = requests.get(url).json()
response
# Out:
# {'kind': 'youtube#searchListResponse',
#  'etag': 'bCBgEcrzwYizE8P-hAIPCfnYpC4',
#  'nextPageToken': 'CDIQAA',
#  'regionCode': 'KR',
#  'pageInfo': {'totalResults': 1000000, 'resultsPerPage': 50},
#  'items': [{'kind': 'youtube#searchResult',
#    'etag': 'XxDo97BTuSNS69MUjBhcZCNL-u8',
#    'id': {'kind': 'youtube#video', 'videoId': 'AOYMwuHJa3Q'},
#    'snippet': {'publishedAt': '2018-01-30T17:03:59Z',
#     'channelId': 'UCBwHqwccpm0a4HAsaPOdG0A',
#     'title': 'Spinners - a short film starring Timothee Chalamet',
#     'description': 'A short film starring: Timothee Chalamet Kristin Slaysman Ify Nwadiwe Directed by: Erik L. Barnes Written by: Cami Delavigne ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/AOYMwuHJa3Q/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/AOYMwuHJa3Q/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
# ...

# %%
print(len(response))
# Out:
# 6

# %%
from youtube_tutorial.youtube_videos import youtube_search
test = youtube_search("spinners")
test
# Out:
# ('CDIQAA',
#  [{'kind': 'youtube#searchResult',
#    'etag': 'XxDo97BTuSNS69MUjBhcZCNL-u8',
#    'id': {'kind': 'youtube#video', 'videoId': 'AOYMwuHJa3Q'},
#    'snippet': {'publishedAt': '2018-01-30T17:03:59Z',
#     'channelId': 'UCBwHqwccpm0a4HAsaPOdG0A',
#     'title': 'Spinners - a short film starring Timothee Chalamet',
#     'description': 'A short film starring: Timothee Chalamet Kristin Slaysman Ify Nwadiwe Directed by: Erik L. Barnes Written by: Cami Delavigne ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/AOYMwuHJa3Q/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/AOYMwuHJa3Q/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/AOYMwuHJa3Q/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Barnacle Films',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2018-01-30T17:03:59Z'}},
# ...
